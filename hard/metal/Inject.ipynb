# %%
import cadquery as cq

s, w = 2.5, 1.

pl = lambda : cq.Workplane( "XY" )

box = pl().box(*( s,) * 3 )

cbase = pl().box(*( s * 3 + 2 * w,) * 2, 7 )
cbase -= pl().box(*( s * 3,) * 3 ).translate(( 0,0,1))

base = cq.Assembly().add( cbase )
base.add( box ) #.translate(( -s /2 - .5, -ladoy / 2 + s/2, 3 - s/2 )))

cav = pl.box
display( base )
